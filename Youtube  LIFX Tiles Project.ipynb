# %% [markdown]
# # Youtube LIFX Tiles Project
#
# Project to Display Youtube Subscriber Count using googleAPIs
#
# Canvas - 1 LIfx Tilechain w/ 5 Tiles
#
# Requires GoogleAPI key with permissions to Youtube dataset
#
# ## Future Projects
#
# - ability to rotate Youtube logo in the case of a minor checkpoint. If Subs is divisible by 10 then rotate the logo on Tile[0] and flash a +10 across the screen before continuing.
# - ability to flash and scoll text on a major checkpoint. If subs is divisible by 100 rotate the logo on Tile[0]. Flash the number of Subs. +100 across the screen.
#
# - ability to flash and scroll text on a huge checkpoint. If subs is dividsible by 1000  make fireworks appear.  :)
#
#
# ## todolist
#
# Need to clear tile color map before writing new number

# %%
import requests
import json
import inflect
from secrets import youtube_api_key

# %%
# Channel_name and API variables
#youtube_api_key = 'AIzaSyDDvCNNmw0Kj1z4XgIx5AQepiZb-akW8F4'
channel_name = 'UCQHfJyIROQhDFUOJKVBiLog'
#channel_name = 'chrisyoungsmarthome'

# %%
data = requests.get("https://www.googleapis.com/youtube/v3/channels?part=statistics&id="+channel_name+"&key="+youtube_api_key)

# %%
data.json()
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"nxOHAKTVB7baOKsQgTtJIyGxcs8/GSfsMhFVDBjRGSHOUSuU6pVT7Qw"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"nxOHAKTVB7baOKsQgTtJIyGxcs8/Q7rwBKPXiCMZpPHE3U88dab-RtA"',
#    'id': 'UCQHfJyIROQhDFUOJKVBiLog',
#    'statistics': {'viewCount': '986108',
#     'commentCount': '0',
#     'subscriberCount': '4900',
#     'hiddenSubscriberCount': False,
#     'videoCount': '208'}}]}

# %%
subs = data.json()['items'][0]['statistics']['subscriberCount']

# %%
import inflect

# %%
for i in subs:
    p = inflect.engine()
    print(p.number_to_words(int(i)))
# Out:
# four
# nine
# zero
# zero

# %%
def get_subs(channel_name, api_key):
    num_of_subs=[]
    data = requests.get("https://www.googleapis.com/youtube/v3/channels?part=statistics&id="+channel_name+"&key="+api_key)
    subs = data.json()['items'][0]['statistics']['subscriberCount']
    for i in subs:
        p = inflect.engine()
        num_of_subs.append(p.number_to_words(int(i)))
    return num_of_subs

# %%
get_subs(channel_name, youtube_api_key)
# Out:
# ['four', 'eight', 'nine', 'zero']

# %%
for number in range(len(get_subs(channel_name, api_key))):
    print (number)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# # Section for Project Code
#
# Using the helper functions above and from other projects, we will put together a small project to display the number of subscribers based on a 30 minute refresh rate ( refresh rate will be variable )

# %%
from lifxlan import *
from random import randint, betavariate
from time import sleep
from secrets import youtube_api_key
from pylifxtiles import actions

channel_name = 'UCQHfJyIROQhDFUOJKVBiLog'


def main():
    lan = LifxLAN()
    tilechain_lights = lan.get_tilechain_lights()
    if len(tilechain_lights) != 0:
        for tile in tilechain_lights:
            if tile.get_label()  ==  'T1':
            #if tile.get_label() == 'TEST':
                T1 = tile
            if tile.get_label()  =='T2':
            #if tile.get_label() == 'TEST':
                T2 = tile
            if tile.get_label()  == 'T3':
            #if tile.get_label() == 'TEST':
                T3 = tile
            if tile.get_label()  == 'T4':
            #if tile.get_label() == 'TEST':
                T4 = tile
            if tile.get_label()  == 'LR1':
            #if tile.get_label() == 'TEST':
                LR = tile
    duration_ms = 1000

    try:
        original_colors = reset_tiles(T1)
        T1.set_tile_colors(0,youtube)
        run = 0
        while(True):
            #T1.set_tile_colors(0,youtube,rapid=True)
            subs = get_subs(channel_name, youtube_api_key)
            tile = 1
            target_color_map = original_colors
            #T1.set_tile_colors(tile, target_color_map[1], rapid=True)
            #T1.set_tile_colors(tile, target_color_map[2], rapid=True)
            #sleep(1)
            for number in subs:
                blank_tile= actions.blank_tile()
                print (len(blank_tile))
                for led in nums[number]:
                    target_color_map[tile][led] = (dblue, 65535, fourty, 4900)
                T1.set_tile_colors(tile, target_color_map[tile], rapid=True)
                tile += 1 
            run += 1
            print ('This is run ' + str(run)+ ' with '+str(subs)+' subscribers')
            sleep(1200)
            
            
    except KeyboardInterrupt:
        print("Done.")
    else:
        print("No TileChain lights found.")


def get_subs(channel_name, api_key):
    num_of_subs=[]
    data = requests.get("https://www.googleapis.com/youtube/v3/channels?part=statistics&id="+channel_name+"&key="+api_key)
    subs = data.json()['items'][0]['statistics']['subscriberCount']
    for i in subs:
        p = inflect.engine()
        num_of_subs.append(p.number_to_words(int(i)))
    return num_of_subs

if __name__=="__main__":
    main()
# Out:
# 64
# 64
# 64
# 64
# This is run 1 with ['four', 'nine', 'one', 'zero'] subscribers
# 64
# 64
# 64
# 64
# This is run 2 with ['four', 'nine', 'one', 'zero'] subscribers
# 64
# 64
# 64
# 64
# This is run 3 with ['four', 'nine', 'one', 'zero'] subscribers
# 64
# 64
# 64
# 64
# This is run 4 with ['four', 'nine', 'one', 'zero'] subscribers
# 64
# 64
# 64
# 64
# This is run 5 with ['four', 'nine', 'one', 'zero'] subscribers
# 64
# 64
# 64
# 64
# This is run 6 with ['four', 'nine', 'one', 'zero'] subscribers
# 64
# 64
# 64
# 64
# This is run 7 with ['four', 'nine', 'one', 'zero'] subscribers
# Done.

# %% [markdown]
# # Section for Helper Code
#
# This section is a placeholder for helper functions and other required variables and constants. Plan is to move these into a python library whos functions can be imported into the script.

# %%
#Youtube Logo Tile Definition
#youtube_tile_definition
youtube = [(42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (42, 0, 59380, 4900),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (42, 0, 59380, 4900),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (42, 0, 59380, 4900),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (42, 65535, 39868, 4900),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500),
 (0, 0, 0, 1500)]

# %%
#two dictionaries alpha and nums which represent a single tile map for a single character or digit

alpha = {'r': [1,
  9,
  17,
  25,
  33,
  41,
  49,
  57,
  2,
  3,
  4,
  13,
  22,
  29,
  34,
  35,
  36,
  44,
  53,
  62],
 't': [1, 2, 3, 4, 5, 6, 11, 19, 27, 35, 43, 51, 59],
 's': [2, 3, 4, 5, 6, 9, 17, 26, 27, 28, 37, 46, 54, 57, 58, 59, 60, 61],
 'u': [1, 6, 9, 14, 17, 22, 25, 30, 33, 38, 41, 46, 49, 54, 59, 59, 60, 61],
 'v': [1, 9, 17, 25, 33, 41, 50, 5, 13, 21, 29, 37, 45, 52, 59],
 'q': [3, 4, 10, 13, 17, 22, 25, 30, 33, 38, 41, 46, 50, 53, 59, 60, 62],
 'w': [1,
  9,
  17,
  25,
  33,
  41,
  57,
  58,
  59,
  60,
  62,
  63],
 'four': [1,
  5,
  6,
  9,
  13,
  14,
  17,
  21,
  22,
  25,
  26,
  27,
  28,
  29,
  30,
  37,
  38,
  45,
  46,
  53,
  54,
  61,
  62],
 'five': [1,
  2,
  3,
  4,
  5,
  6,
  9,
  17,
  25,
  26,
  27,
  28,
  29,
  38,
  46,
  54,
  57,
  58,
  59,
  60,
  61],
 'six': [3,
  4,
  5,
  10,
  17,
  25,
  33,
  35,
  36,
  37,
  38,
  41,
  42,
  46,
  49,
  54,
  58,
  59,
  60,
  61],
 'seven': [1, 2, 3, 4, 5, 6, 14, 22, 30, 37, 44, 51, 58],
 'eight': [2,
  3,
  4,
  5,
  9,
  14,
  18,
  21,
  27,
  28,
  34,
  37,
  41,
  46,
  49,
  54,
  58,
  59,
  60,
  61],
 'nine': [3,
  4,
  10,
  13,
  17,
  22,
  25,
  30,
  34,
  35,
  36,
  37,
  38,
  46,
  54,
  59,
  60,
  61,
  63]}

# %%
#color_saturation need to play with more to make sure that straight math division gets wanted results
no_color = 0
color_ten = 65535/10
color_twenty = (65535/10)*2
color_thirty = (65535/10)*3
color_fourty = (65535/10)*4
color_fifty = (65535/10)*5
color_sixty = (65535/10)*6
color_seventy = (65535/10)*7
color_eighty = (65535/10)*8
color_ninety = (65535/10)*9
full_color = 65535


#brightness - based off values assigned from LIFX app
off = 0
one = 1310
ten = 6823
twenty = 13312
thirty = 20009
fourty = 26313
fifty = 33102
sixty = 39868
seventy = 46334
eighty = 52730
ninety = 59380
hundread = 65523

#warmth - based off values assigned from LIFX app - took the high end of a given category
ultrawarm = 2500
incandescent = 2800
warm = 3200
neutral = 3700
cool = 4200
cooldaylight = 4700
softdaylight = 5200
daylight = 5700
noondaylight = 6200
brightdaylight = 6700
cloudydaylight = 7200
bluedaylight = 7700
blueovercast = 8450
blueice = 9000

# %%
#create colors list - based on visual verification of the colors using the LIFX app
red = 42
orange = 5439
yellow = 12230
green = 18017
lblue = 34238
dblue = 45793
indigo = 50580
violet = 58572

# %%
def reset_tiles(my_tile):
    global original_colors
    original_colors = my_tile.get_tilechain_colors()
    for i in range(0,64):
        original_colors[0][i] = (0, 0, 0, 1500)
        original_colors[1][i] = (0, 0, 0, 1500)
        original_colors[2][i] = (0, 0, 0, 1500)
        original_colors[3][i] = (0, 0, 0, 1500)
        original_colors[4][i] = (0, 0, 0, 1500)
    my_tile.set_tilechain_colors(original_colors)
    return original_colors

# %%
reset_tiles(T1)
# Out:
# [[(0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
#   (0, 0, 0, 1500),
# ...

# %%
from lifxlan import *

lan = LifxLAN()
tilechain_lights = lan.get_tilechain_lights()
if len(tilechain_lights) != 0:
    for tile in tilechain_lights:
        if tile.get_label()  ==  'T1':
        #if tile.get_label() == 'TEST':
            T1 = tile
        if tile.get_label()  =='T2':
        #if tile.get_label() == 'TEST':
            T2 = tile
        if tile.get_label()  == 'T3':
        #if tile.get_label() == 'TEST':
            T3 = tile
        if tile.get_label()  == 'T4':
        #if tile.get_label() == 'TEST':
            T4 = tile
        if tile.get_label()  == 'LR1':
        #if tile.get_label() == 'TEST':
            LR = tile
T1
